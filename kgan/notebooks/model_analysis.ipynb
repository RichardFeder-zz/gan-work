# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rcParams['font.size'] = 16.0

# %%
import keras.models as km
# Out:
# Using TensorFlow backend.

# %%
10 // 10
# Out:
# 1

# %%
import h5py
import glob

# %%
from keras.backend.tensorflow_backend import set_session
from keras.backend.tensorflow_backend import clear_session
from keras.backend.tensorflow_backend import get_session
import tensorflow
import gc

# Reset Keras Session
def reset_keras(model):
    
    sess = get_session()
    clear_session()
    sess.close()
    sess = get_session()

    print(gc.collect()) # if it's done something you should see a number being outputted
    
    try:
        del model # this is from global space - change this as you need
    except:
        pass

    # use the same config as you used to create the session
    #config = tensorflow.ConfigProto()
    #config.gpu_options.per_process_gpu_memory_fraction = 1
    #config.gpu_options.visible_device_list = "0"
    #set_session(tensorflow.Session(config=config))

# %%
hist_list = glob.glob("/work/06147/pberger/maverick2/saved_models/*011[4-7].history5")
#hist_list.pop(3)
hist_list = np.sort(hist_list)
hist_list
# Out:
# array(['/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.history5',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.history5',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.history5',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.history5'],
#       dtype='|S70')

# %%
# !diff ../scripts/config_001.yaml ../scripts/config_00114.yaml
# Out:
# 1,2c1,2
# < save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_001.keras'
# < save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_001.history5'
# ---
# > save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras'
# > save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.history5'
# 10c10
# <     nepochs          : 25
# ---
# >     nepochs          : 30
# 34c34
# <         decay  : 1e-5
# ---
# >         decay  : 1.5e-4

# %%
#
# !diff ../scripts/config_00114.yaml ../scripts/config_00115.yaml
# Out:
# 1,2c1,2
# < save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras'
# < save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.history5'
# ---
# > save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras'
# > save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.history5'
# 11c11
# <     latent_dim       : 100
# ---
# >     latent_dim       : 192

# %%
#
# !diff ../scripts/config_00114.yaml ../scripts/config_00116.yaml
# Out:
# 1,2c1,2
# < save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras'
# < save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.history5'
# ---
# > save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras'
# > save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.history5'
# 18c18
# <             base_features      : 32
# ---
# >             base_features      : 48

# %%
#
# !diff ../scripts/config_00114.yaml ../scripts/config_00117.yaml
# Out:
# 1,2c1,2
# < save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras'
# < save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.history5'
# ---
# > save_model : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras'
# > save_history : '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.history5'
# 11c11
# <     latent_dim       : 100
# ---
# >     latent_dim       : 192
# 18c18
# <             base_features      : 32
# ---
# >             base_features      : 48

# %%
model_list1 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_001.keras*"))
model_list2 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_002.keras*"))
model_list3 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_003.keras*"))
model_list4 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_004.keras*"))

# %%
model_list1 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_0010.keras*"))
model_list2 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_0011.keras*"))
model_list3 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_0012.keras*"))
model_list4 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_0013.keras*"))

# %%
model_list1 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00110.keras*"))
model_list2 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00111.keras*"))
model_list3 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00112.keras*"))
model_list4 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00113.keras*"))

# %%
model_list1 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00114.keras*"))
model_list2 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00115.keras*"))
model_list3 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00116.keras*"))
model_list4 = np.sort(glob.glob("/work/06147/pberger/maverick2/saved_models/*_00117.keras*"))

# %%
from kgan.net.gp_loss import *

# %%
import keras.losses
keras.losses.custom_loss = wasserstein_loss

# %%
from keras.utils.generic_utils import get_custom_objects

# %%
get_custom_objects().update({"wasserstein_loss": wasserstein_loss})

# %%
#model = km.load_model(model_list1[0])

# %%
from kgan.tools.delta import *

# %%
# Load the data
fp = "/work/06147/pberger/maverick2/gadget_runs/cosmo1/n512_512Mpc_cosmo1_z0_gridpart.h5"

with h5py.File(fp, 'r') as data:
    
    delta = []
    for dk in list(data.keys())[:1]:
        delta_i = squash(data[dk][:])
        delta_i = np.array(split3d(delta_i, 8))
        delta.extend(delta_i)
    delta = np.array(delta)
    
print(delta.shape)
# Out:
# (512, 64, 64, 64)

# %%
mi = 0
model = km.load_model(model_list1[mi])
# Out:
# /home1/06147/pberger/.virtualenvs/tensorflow/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
fig = figure(figsize = (10, 5))

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

subplot(1,2,1)
imshow(test_imgs[0, 32])
colorbar()
subplot(1,2,2)
imshow(real_imgs[0, 32])
#print(np.std(real_imgs.reshape(32, -1), axis=-1).mean(), np.mean(real_imgs.reshape(32, -1), axis=-1).mean())
#print(np.std(test_img.reshape(32, -1), axis=-1).mean(), np.mean(test_imgs.reshape(32, -1), axis=-1).mean())
colorbar()

# %%
def estimate_pk(kki, img, nbin=30):
    
    bins = np.linspace(np.min(kki), np.max(kki), nbin+1, endpoint=True)

    ibin = [np.logical_and(kki.ravel() >= bins[i], kki.ravel() < bins[i+1]) for i in range(nbin)]
    ibin = np.array(ibin)

    ft = abs(np.fft.fftn(img))**2
    pkk = np.array([np.mean(ft.ravel()[ibin[i]]) for i in range(nbin)])
    kk = np.array([np.mean(kki.ravel()[ibin[i]]) for i in range(nbin)])

    return kk, pkk

# %%
def quick_check_plot(real_imgs, test_imgs):

    fig = figure(figsize = (15, 5))

    kx = np.fft.fftfreq(64, d=0.1)
    ky = np.fft.fftfreq(64, d=0.1)
    kz = np.fft.fftfreq(64, d=0.1)
    kk = np.sqrt(kx[:, np.newaxis, np.newaxis]**2 
                 + ky[np.newaxis, :, np.newaxis]**2 
                 + kz[np.newaxis, np.newaxis, :]**2)

    pk1r = []
    pk2f = []
    for i in range(32):
        k1, pk1 = estimate_pk(kk, squash_inv(real_imgs[i]))
        k2, pk2 = estimate_pk(kk, squash_inv(test_imgs[i]))
        #k1, pk1 = estimate_pk(kk, real_imgs[i])
        #k2, pk2 = estimate_pk(kk, test_imgs[i])

        pk1r.append(pk1)
        pk2f.append(pk2)
    pk1r = np.array(pk1r)
    pk2f = np.array(pk2f)

    subplot(2,2,1)
    plot(k1, pk1r.mean(0), '-o')
    fill_between(k1, pk1r.mean(0) - pk1r.std(0), pk1r.mean(0) + pk1r.std(0), color='C0', alpha=0.1)
    plot(k2, pk2f.mean(0), '-o')
    fill_between(k2, pk2f.mean(0) - pk2f.std(0), pk2f.mean(0) + pk2f.std(0), color='C1', alpha=0.1)
    yscale('log')
    xscale('log')
    subplot(2,2,3)
    plot(k1, np.sqrt(pk2f.mean(0)/pk1r.mean(0)), '-o')
    krange = np.linspace(np.min(k1), np.max(k1), 100)
    fill_between(krange, np.ones_like(krange)*0.9, np.ones_like(krange)*1.1, color='C5', alpha=0.1)
    fill_between(krange, np.ones_like(krange)*0.95, np.ones_like(krange)*1.05, color='C5', alpha=0.2)
    axhline(1.0, ls='--', c='grey')
    xscale('log')
    ylim(0.75, 1.25)

    subplot(1,2,2)
    foo = hist((real_imgs).ravel(), bins=50, edgecolor='C0', alpha=0.1)
    foot = hist((test_imgs).ravel(), bins=50, edgecolor='C1', alpha=0.1)
    #foo = hist(squash_inv(real_imgs).ravel(), bins=50, edgecolor='C0', alpha=0.1)
    #foot = hist(squash_inv(test_imgs).ravel(), bins=50, edgecolor='C1', alpha=0.1)
    yscale('log')

# %%
fig = figure(figsize = (15, 12))

titles=['decay=1.5e-4', 'decay=1.5e-4,latent_dim=192', 'decay=1e.5e-4,base_features=48', 'all of the above']

for mi in range(4):
    subplot(4,1,1+mi)
    with h5py.File(hist_list[mi], 'r') as hfile:

        epoch = np.arange(hfile['g_loss'][:].shape[0])*30./hfile['g_loss'][:].shape[0]
        plot(epoch, hfile['d_loss'][:], '.')
        plot(epoch, hfile['g_loss'][:], '.')
        
        title(titles[mi])

    ylim(-100, 100)
    
tight_layout()

# %%
latent_dim=100

# %%
model_list = model_list1
print(len(model_list))
model_list
# Out:
# 22
# array(['/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-005',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-007',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-009',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-011',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-012',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-013',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-014',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-015',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-016',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-017',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-018',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-019',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-020',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-021',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-022',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-023',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-024',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-025',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-026',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-027',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-028',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00114.keras-029'],
#       dtype='|S71')

# %%
mi = 0
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# /home1/06147/pberger/.virtualenvs/tensorflow/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
mi = 1
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 2
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 3
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 4
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 5
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 6
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 7
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 8
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 9
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 10
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 11
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 12
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 13
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 14
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 15
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 16
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 17
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 18
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 19
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 20
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 21
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
latent_dim=192

# %%
model_list = model_list2
print(len(model_list))
model_list
# Out:
# 22
# array(['/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-005',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-007',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-009',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-011',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-012',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-013',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-014',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-015',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-016',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-017',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-018',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-019',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-020',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-021',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-022',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-023',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-024',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-025',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-026',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-027',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-028',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00115.keras-029'],
#       dtype='|S71')

# %%
mi = 0
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 1
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 2
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 3
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 4
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 5
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 6
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 7
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 8
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 9
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 10
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 11
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 12
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 13
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 14
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 15
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 16
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 17
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 18
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 19
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 20
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 21
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
latent_dim=100

# %%
model_list = model_list3
print(len(model_list))
model_list
# Out:
# 22
# array(['/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-005',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-007',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-009',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-011',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-012',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-013',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-014',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-015',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-016',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-017',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-018',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-019',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-020',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-021',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-022',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-023',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-024',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-025',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-026',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-027',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-028',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00116.keras-029'],
#       dtype='|S71')

# %%
mi = 0
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# /home1/06147/pberger/.virtualenvs/tensorflow/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
mi = 1
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 2
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 3
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 4
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 5
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# /home1/06147/pberger/.virtualenvs/tensorflow/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
mi = 6
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 7
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
mi = 8
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
reset_keras(model)

mi = 9
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 20529

# %%
reset_keras(model)

mi = 10
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 111021

# %%
reset_keras(model)

mi = 11
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 110968

# %%
reset_keras(model)

mi = 13
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114343

# %%
reset_keras(model)

mi = 15
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 113883

# %%
reset_keras(model)

mi = 17
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114330

# %%
reset_keras(model)

mi = 19
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114342

# %%
reset_keras(model)

mi = 20
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 113873

# %%
reset_keras(model)

mi = 21
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114298

# %%
latent_dim=192

# %%
model_list = model_list4
print(len(model_list))
model_list
# Out:
# 22
# array(['/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-005',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-007',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-009',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-011',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-012',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-013',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-014',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-015',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-016',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-017',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-018',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-019',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-020',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-021',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-022',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-023',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-024',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-025',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-026',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-027',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-028',
#        '/work/06147/pberger/maverick2/saved_models/gen_resnet3d_00117.keras-029'],
#       dtype='|S71')

# %%
mi = 1
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# /home1/06147/pberger/.virtualenvs/tensorflow/lib/python2.7/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
reset_keras(model)
# Out:
# 20003

# %%
mi = 2
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
reset_keras(model)

mi = 3
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 110998

# %%
reset_keras(model)

mi = 4
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 111050

# %%
reset_keras(model)

mi = 5
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 111037

# %%
reset_keras(model)

mi = 6
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 110445

# %%
reset_keras(model)

mi = 7
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114881

# %%
reset_keras(model)

mi = 8
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 110413

# %%
reset_keras(model)

mi = 9
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 113877

# %%
reset_keras(model)

mi = 10
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114447

# %%
reset_keras(model)

mi = 11
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 110902

# %%
reset_keras(model)

mi = 13
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 114330

# %%
reset_keras(model)

mi = 15
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 113823

# %%
reset_keras(model)

mi = 17
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
# Out:
# 113840

# %%
mi = 19
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)

# %%
reset_keras(model)
# Out:
# 234

# %%
mi = 21
model = km.load_model(model_list[mi])

test_imgs = model.predict(np.random.normal(0, 1, (32, latent_dim))).reshape(32, 64, 64, 64)
real_imgs = delta[:32]
    
test_imgs = np.array(test_imgs)
real_imgs = np.array(real_imgs)

quick_check_plot(real_imgs, test_imgs)
